# %% [markdown]
# <h1><center>MLDSL Demo</center></h1>
# <a id="tc"></a>
#
# ## Table of Contents
# 1. [Configuration](#configuration)
# 2. [Local Source Changes](#files)
# 2. [Prepare Signature](#signature)
# 3. [Train and Tune LGBM Model](#hptuning)
# 4. [Trained Model Deployment](#deployment)
# 5. [Batch Prediction](#prediction)

# %% [markdown]
# <a id="configuration"></a>
# ## Configuration
# [back to Table Of Contents](#tc)

# %%
import os
import json

def get_transition(transition_file):
    with open(transition_file, 'r') as f:
        return json.load(f)

# %%
BASE_PATH='/home/jovyan/work/data'
PROJECT_PATH = f'{BASE_PATH}/demo'

SCRIPT_PATH=f'{PROJECT_PATH}/scripts'
BUCKET = 'ai4ops'
PROJECT = 'gd-gcp-techlead-experiments'
CLUSTER = 'ai4ops'
REGION='global'
AI_PLATFORM_REGION = 'us-central1'

AI_PALTFORM_MODEL_NAME='ai4ops_lgbm_throughput'

# %%
from mldsl import *
import importlib
from datetime import datetime
import sys
import pyspark

# %% [markdown]
# <a id="files"></a>
# ## Local Source Changes
# [back to Table Of Contents](#tc)

# %%
# %%py_script --exec True --name gs_utils.py --path demo/scripts
# #!/usr/bin/python
# from google.cloud import storage
#
# def get_bucket(bucket_id, project):
#     client = storage.Client(project)
#     return client.get_bucket(bucket_id)
#
#
# def upload_to_gs(bct, folder_path_gs, file):
#     blob = bct.blob(folder_path_gs + '/' + file)
#     blob.upload_from_filename(file)
#
# def print_text(text):
#     print(text)
#
# print_text(get_bucket(BUCKET, PROJECT).__dict__)
# Out:
# Script output:
#  {'name': 'ai4ops', '_properties': {'kind': 'storage#bucket', 'id': 'ai4ops', 'selfLink': 'https://www.googleapis.com/storage/v1/b/ai4ops', 'projectNumber': '713133371133', 'name': 'ai4ops', 'metageneration': '7', 'location': 'US-EAST1', 'storageClass': 'REGIONAL', 'etag': 'CAc=', 'iamConfiguration': {'bucketPolicyOnly': {'enabled': False}, 'uniformBucketLevelAccess': {'enabled': False}}, 'locationType': 'region', 'timeCreated': '2019-04-09T10:30:07.044Z', 'updated': '2019-10-02T12:39:53.418Z'}, '_changes': set(), '_client': <google.cloud.storage.client.Client object at 0x7f94f55709e8>, '_acl': <google.cloud.storage.acl.BucketACL object at 0x7f94f5570908>, '_default_object_acl': <google.cloud.storage.acl.DefaultObjectACL object at 0x7f94f5570f98>, '_label_removals': set(), '_user_project': None}

# %% [markdown]
# <a id="signature"></a>
# ## Prepare LGBM Signature
# [back to Table Of Contents](#tc)

# %%
builder = DataprocJobBuilder()
session = GCPSessionFactory.build_session(job_bucket=BUCKET,job_region=REGION, cluster=CLUSTER, job_project_id=PROJECT, 
                                          ml_region=AI_PLATFORM_REGION)

# %%
AI_PLATFORM_MODEL_BASE_VERSION = 'v1'

OUTPUT_PATH = 'demo_models/lgbm/input'
USE_POWER_TRANSFORMER = 'True'
WITH_CALENDAR_FEATURES = 'False'
SCALER_NAME = ""


CONFIG_FILENAME = 'lgbm_signature_august_throughput.json'
DATA_CONFIG = f'{PROJECT_PATH}/config/{CONFIG_FILENAME}'

SIGNATURE_INPUT=f'gs://{BUCKET}/demo/part-00000-b4a31031-df3f-4d82-945e-7b9b71ea790c-c000.csv'

# %%
builder = DataprocJobBuilder()

TIMESTAMP=int(datetime.now().timestamp())
sign_job_name = f"dsl_ai4ops_demo_signature_{TIMESTAMP}"

SIGNATURE_OUT = f"{OUTPUT_PATH}/{sign_job_name}"

arguments = Arguments()
arguments.set_args(**{"--input_data_path":SIGNATURE_INPUT,\
             "--config": CONFIG_FILENAME,\
             "--output_bucket":BUCKET,\
             "--output_bucket_project": PROJECT,\
            "--output_bucket_path":SIGNATURE_OUT,\
             "--workflow_id":str(TIMESTAMP),\
             "--with_calendar_features": WITH_CALENDAR_FEATURES, \
            "--with_power_transform": USE_POWER_TRANSFORMER \
            })

if SCALER_NAME:
    arguments.set_arg('--scaler_name', SCALER_NAME)

signature_job = builder.files_root(SCRIPT_PATH)\
.job_file('partial_signature_lgbm.py')\
.job_id(sign_job_name)\
.py_file('apigee_ingest_utils.py')\
.py_file('ai4ops_db.py')\
.py_file('yarn_logging.py')\
.py_script('gs_utils.py')\
.file(DATA_CONFIG)\
.arguments(arguments)\
.build_job()



signature_executor = DataprocExecutor(signature_job, session)

# %%
signature_res = signature_executor.submit_job(run_async=False)
# Out:
# Uploading file from dir: jobs-root/dsl_ai4ops_demo_signature_1570198312/partial_signature_lgbm.py
# Uploading file from dir: jobs-root/dsl_ai4ops_demo_signature_1570198312/apigee_ingest_utils.py
# Uploading file from dir: jobs-root/dsl_ai4ops_demo_signature_1570198312/ai4ops_db.py
# Uploading file from dir: jobs-root/dsl_ai4ops_demo_signature_1570198312/yarn_logging.py
# Uploading file from dir: jobs-root/dsl_ai4ops_demo_signature_1570198312/lgbm_signature_august_throughput.json
# Job with id dsl_ai4ops_demo_signature_1570198312 was submitted to the cluster ai4ops
# Job STATUS was set to PENDING at 2019-10-04 14:11:54
# Job STATUS was set to SETUP_DONE at 2019-10-04 14:11:54
#       Yarn APP /home/jovyan/work/data/demo/scripts/partial_signature_lgbm.py with STATUS ACCEPTED has PROGRESS 0
#       Yarn APP /home/jovyan/work/data/demo/scripts/partial_signature_lgbm.py with STATUS RUNNING has PROGRESS 10
# Job STATUS was set to RUNNING at 2019-10-04 14:11:54
#       Yarn APP /home/jovyan/work/data/demo/scripts/partial_signature_lgbm.py with STATUS FINISHED has PROGRESS 100
# Job STATUS was set to DONE at 2019-10-04 14:13:03

# %%
signature_executor.get_job()
# Out:
# ---------------------------------------------------------------------------
# _Rendezvous                               Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/google/api_core/grpc_helpers.py in error_remapped_callable(*args, **kwargs)
#      56         try:
# ---> 57             return callable_(*args, **kwargs)
#      58         except grpc.RpcError as exc:
#
# /opt/conda/lib/python3.7/site-packages/grpc/_channel.py in __call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     564                                       wait_for_ready, compression)
# --> 565         return _end_unary_response_blocking(state, call, False, None)
#     566
#
# /opt/conda/lib/python3.7/site-packages/grpc/_channel.py in _end_unary_response_blocking(state, call, with_call, deadline)
#     466     else:
# --> 467         raise _Rendezvous(state, None, None, deadline)
#     468
#
# _Rendezvous: <_Rendezvous of RPC that terminated with:
# 	status = StatusCode.NOT_FOUND
# 	details = "Not found: Job projects/gd-gcp-techlead-experiments/regions/global/jobs/dsl_ai4ops_demo_signature_1570457542"
# 	debug_error_string = "{"created":"@1570461750.548941779","description":"Error received from peer ipv4:172.217.212.95:443","file":"src/core/lib/surface/call.cc","file_line":1052,"grpc_message":"Not found: Job projects/gd-gcp-techlead-experiments/regions/global/jobs/dsl_ai4ops_demo_signature_1570457542","grpc_status":5}"
# >
#
# The above exception was the direct cause of the following exception:
#
# NotFound                                  Traceback (most recent call last)
# <ipython-input-36-cab3797a21cf> in <module>
# ----> 1 signature_executor.get_job()
#
# ~/work/data/mldsl.py in get_job(self)
#    1234
#    1235         job = self.__session._dataproc_job_client.get_job(self.__session.project_id, self.__session.region,
# -> 1236                                                           self.__job.job_id)
#    1237         self.job_status = job.status.State.Name(job.status.state)
#    1238         self.__status_history = job.status_history
#
# /opt/conda/lib/python3.7/site-packages/google/cloud/dataproc_v1/gapic/job_controller_client.py in get_job(self, project_id, region, job_id, retry, timeout, metadata)
#     324         )
#     325         return self._inner_api_calls["get_job"](
# --> 326             request, retry=retry, timeout=timeout, metadata=metadata
#     327         )
#     328
#
# /opt/conda/lib/python3.7/site-packages/google/api_core/gapic_v1/method.py in __call__(self, *args, **kwargs)
#     141             kwargs["metadata"] = metadata
#     142
# --> 143         return wrapped_func(*args, **kwargs)
#     144
#     145
#
# /opt/conda/lib/python3.7/site-packages/google/api_core/retry.py in retry_wrapped_func(*args, **kwargs)
#     268                 sleep_generator,
#     269                 self._deadline,
# --> 270                 on_error=on_error,
#     271             )
#     272
#
# /opt/conda/lib/python3.7/site-packages/google/api_core/retry.py in retry_target(target, predicate, sleep_generator, deadline, on_error)
#     177     for sleep in sleep_generator:
#     178         try:
# --> 179             return target()
#     180
#     181         # pylint: disable=broad-except
#
# /opt/conda/lib/python3.7/site-packages/google/api_core/timeout.py in func_with_timeout(*args, **kwargs)
#     212             """Wrapped function that adds timeout."""
#     213             kwargs["timeout"] = next(timeouts)
# --> 214             return func(*args, **kwargs)
#     215
#     216         return func_with_timeout
#
# /opt/conda/lib/python3.7/site-packages/google/api_core/grpc_helpers.py in error_remapped_callable(*args, **kwargs)
#      57             return callable_(*args, **kwargs)
#      58         except grpc.RpcError as exc:
# ---> 59             six.raise_from(exceptions.from_grpc_error(exc), exc)
#      60
#      61     return error_remapped_callable
#
# /opt/conda/lib/python3.7/site-packages/six.py in raise_from(value, from_value)
#
# NotFound: 404 Not found: Job projects/gd-gcp-techlead-experiments/regions/global/jobs/dsl_ai4ops_demo_signature_1570457542

# %%
state = signature_executor.get_job_state()

print('State : {}'.format(state))
if state not in ['DONE', 'RUNNING']:
    raise RuntimeError('Previous workflow step was failed')
# Out:
# State : DONE

# %%
transition_signature = {
    "SIGNATURE_JOB_ID": sign_job_name,
    "SIGNATURE_TIMESTAMP": TIMESTAMP,
    "SIGNATURE_BUCKET": BUCKET,
    "SIGNATURE_TRAIN": f"{SIGNATURE_OUT}/LGBM-TRAIN-{TIMESTAMP}.csv",
    "SIGNATURE_VAL": f"{SIGNATURE_OUT}/LGBM-VAL-{TIMESTAMP}.csv",
    "SIGNATURE_TEST": f"{SIGNATURE_OUT}/LGBM-TEST-{TIMESTAMP}.csv",
    "SIGNATURE_SCALER": f"{SIGNATURE_OUT}/LGBM-SCL-{TIMESTAMP}.pkl",
    "SIGNATURE_DROP_KEYS": f"{SIGNATURE_OUT}/LGBM-DROP-KEYS-{TIMESTAMP}.txt",
    "SIGNATURE_STATE": state
}

print(transition_signature)

with open('transitions/dsl_transition_signature.json', 'w') as file:
     file.write(json.dumps(transition_signature))

# %% [markdown]
# <a id="hptuning"></a>
# ## Train and Tune LGBM Model
# [back to Table Of Contents](#tc)

# %%
SCRIPT_PATH = f"{PROJECT_PATH}/model"
signature_transition = get_transition('transitions/dsl_transition_signature.json')
print(signature_transition)
state = signature_transition.get('SIGNATURE_STATE', '')
print('State: {}'.format(state))
if state not in ['DONE']:
    raise RuntimeError('Previous workflow step was failed')


SIGNATURE_TRAIN = signature_transition.get('SIGNATURE_TRAIN', '')
SIGNATURE_VAL = signature_transition.get('SIGNATURE_VAL', '')
SIGNATURE_TEST = signature_transition.get('SIGNATURE_TEST', '')
SIGNATURE_SCALER = signature_transition.get('SIGNATURE_SCALER', '')
CATEGORICAL_COLUMNS = 'metric_class'
EXCLUDED_COLUMNS =  'time,metric,metric_id'

TUNING_CONFIG_FILE='demo/config/hptuning_config.yaml'
WAIT_DELAY='60'
WAIT_TRIES='6'
SCALE_TIER="custom"
# Out:
# {'SIGNATURE_JOB_ID': 'dsl_ai4ops_demo_signature_1570198312', 'SIGNATURE_TIMESTAMP': 1570198312, 'SIGNATURE_BUCKET': 'ai4ops', 'SIGNATURE_TRAIN': 'demo_models/lgbm/input/dsl_ai4ops_demo_signature_1570198312/LGBM-TRAIN-1570198312.csv', 'SIGNATURE_VAL': 'demo_models/lgbm/input/dsl_ai4ops_demo_signature_1570198312/LGBM-VAL-1570198312.csv', 'SIGNATURE_TEST': 'demo_models/lgbm/input/dsl_ai4ops_demo_signature_1570198312/LGBM-TEST-1570198312.csv', 'SIGNATURE_SCALER': 'demo_models/lgbm/input/dsl_ai4ops_demo_signature_1570198312/LGBM-SCL-1570198312.pkl', 'SIGNATURE_DROP_KEYS': 'demo_models/lgbm/input/dsl_ai4ops_demo_signature_1570198312/LGBM-DROP-KEYS-1570198312.txt', 'SIGNATURE_STATE': 'DONE'}
# State: DONE

# %%
TIMESTAMP=int(datetime.now().timestamp())
TUNING_JOB_NAME=f"dsl_demo_tuning_lgbm_{TIMESTAMP}"
JOB_DIR=f"gs://{BUCKET}/demo/models/lightgbm/{TUNING_JOB_NAME}"#fix path
ERR_LOG_PATH_GS=f"demo/models/lightgbm/{TUNING_JOB_NAME}/output"
TRAINED_MODEL_PATH_GS = f"demo/models/lightgbm/{TUNING_JOB_NAME}/model"


training_input = {
  "region": AI_PLATFORM_REGION,
  "scaleTier": SCALE_TIER,
  "masterType":"large_model",\
  "workerType":"large_model",\
  "parameterServerType":"large_model",\
  "workerCount":"4",\
  "parameterServerCount":"3",\
  "masterConfig": {
    "imageUri": "gcr.io/gd-gcp-techlead-experiments/ai4ops_lgbm_image"
  },
  "jobDir": JOB_DIR
}

args = Arguments ()
args.set_args(**{
    '--is_hyperparameters_tuning': 'True',\
    '--bucket_id': BUCKET, \
  '--train_data_path_gs': SIGNATURE_TRAIN, \
  '--val_data_path_gs': SIGNATURE_VAL, \
  '--err_log_path_gs': ERR_LOG_PATH_GS, \
  '--trained_model_path_gs': TRAINED_MODEL_PATH_GS, \
  '--boosting_type': "gbdt", \
  '--n_jobs': '-1', \
  '--early_stopping_rounds': '10', \
  '--importance_type': "split", \
  '--categorical_feature': CATEGORICAL_COLUMNS, \
  '--target': "var1(t)", \
  '--excluded': EXCLUDED_COLUMNS
})

m_builder = ModelBuilder()

model = m_builder.train_image_uri('gcr.io/gd-gcp-techlead-experiments/ai4ops_lgbm_image')\
.name(AI_PALTFORM_MODEL_NAME)\
.train_arguments(args)\
.files_root(SCRIPT_PATH)\
.custom_predictor_path("setup.py")\
.build()

ai_job_builder = AIJobBuilder()

ai_tuning_job = ai_job_builder.model(model)\
.train_input(training_input)\
.name(TUNING_JOB_NAME)\
.load_hyperparameters_from_file(TUNING_CONFIG_FILE)\
.job_dir(JOB_DIR)\
.build()

# %%
tuning_executor = AIPlatformJobExecutor(session,ai_tuning_job, 60, 10)

response = tuning_executor.submit_train_job()
state = response['state']

# %%
transition_tuning = {
    "TRAIN_JOB_ID": TUNING_JOB_NAME,
    "TRAIN_JOB_DIR": JOB_DIR,
    "TRAIN_STATE": state,
    "TRAINED_MODEL": f"{JOB_DIR}/model",
    "IS_TUNING":True
}

print(transition_tuning)

with open('transitions/dsl_transition_tuning.json', 'w') as file:
     file.write(json.dumps(transition_tuning))
# Out:
# {'TRAIN_JOB_ID': 'dsl_demo_tuning_lgbm_1570212734', 'TRAIN_JOB_DIR': 'gs://ai4ops/ai4ops/demo/models/lightgbm/dsl_demo_tuning_lgbm_1570212734', 'TRAIN_STATE': 'SUCCEEDED', 'TRAINED_MODEL': 'gs://ai4ops/ai4ops/demo/models/lightgbm/dsl_demo_tuning_lgbm_1570212734/model', 'IS_TUNING': True}

# %%
ml_session = session.get_ml_session()
AIPlatformJobExecutor.get_job(ml_session, f'projects/{ml_session.project_id}/jobs/dsl_demo_tuning_lgbm_1570212734')
# Out:
# {'jobId': 'dsl_demo_tuning_lgbm_1570212734',
#  'trainingInput': {'scaleTier': 'CUSTOM',
#   'masterType': 'large_model',
#   'workerType': 'large_model',
#   'parameterServerType': 'large_model',
#   'workerCount': '4',
#   'parameterServerCount': '3',
#   'args': ['--is_hyperparameters_tuning',
#    'True',
#    '--bucket_id',
#    'ai4ops',
#    '--train_data_path_gs',
#    'demo_models/lgbm/input/dsl_ai4ops_demo_signature_1570198312/LGBM-TRAIN-1570198312.csv',
#    '--val_data_path_gs',
#    'demo_models/lgbm/input/dsl_ai4ops_demo_signature_1570198312/LGBM-VAL-1570198312.csv',
#    '--err_log_path_gs',
#    'demo/models/lightgbm/dsl_demo_tuning_lgbm_1570212734/output',
#    '--trained_model_path_gs',
#    'demo/models/lightgbm/dsl_demo_tuning_lgbm_1570212734/model',
#    '--boosting_type',
#    'gbdt',
#    '--n_jobs',
#    '-1',
#    '--early_stopping_rounds',
#    '10',
#    '--importance_type',
#    'split',
#    '--categorical_feature',
#    'metric_class',
#    '--target',
#    'var1(t)',
#    '--excluded',
#    'time,metric,metric_id'],
#   'hyperparameters': {'goal': 'MINIMIZE',
#    'params': [{'parameterName': 'colsample_bytree',
#      'minValue': 0.001,
#      'maxValue': 1,
#      'type': 'DOUBLE'},
#     {'parameterName': 'learning_rate',
#      'minValue': 0.0001,
#      'maxValue': 1,
#      'type': 'DOUBLE'},
#     {'parameterName': 'max_depth',
#      'minValue': 5,
#      'maxValue': 100,
#      'type': 'INTEGER'},
#     {'parameterName': 'min_child_samples',
#      'minValue': 1,
#      'maxValue': 200,
#      'type': 'INTEGER'},
#     {'parameterName': 'min_child_weight',
#      'minValue': 0.001,
#      'maxValue': 100,
#      'type': 'DOUBLE'},
#     {'parameterName': 'min_split_gain', 'maxValue': 1, 'type': 'DOUBLE'},
#     {'parameterName': 'n_estimators',
#      'minValue': 50,
#      'maxValue': 700,
#      'type': 'INTEGER'},
#     {'parameterName': 'num_leaves',
#      'minValue': 100,
#      'maxValue': 1000,
#      'type': 'INTEGER'},
#     {'parameterName': 'reg_alpha', 'maxValue': 100, 'type': 'DOUBLE'},
#     {'parameterName': 'reg_lambda', 'maxValue': 100, 'type': 'DOUBLE'},
#     {'parameterName': 'subsample',
#      'minValue': 0.001,
#      'maxValue': 1,
#      'type': 'DOUBLE'},
#     {'parameterName': 'subsample_freq', 'maxValue': 100, 'type': 'INTEGER'}],
#    'maxTrials': 50,
#    'maxParallelTrials': 10,
#    'hyperparameterMetricTag': 'ai4ops_lightgbm_mae_tag',
#    'enableTrialEarlyStopping': True},
#   'region': 'us-central1',
#   'jobDir': 'gs://ai4ops/ai4ops/demo/models/lightgbm/dsl_demo_tuning_lgbm_1570212734',
#   'masterConfig': {'imageUri': 'gcr.io/gd-gcp-techlead-experiments/ai4ops_lgbm_image'}},
#  'createTime': '2019-10-04T18:12:17Z',
#  'startTime': '2019-10-04T18:12:21Z',
#  'endTime': '2019-10-04T18:34:22Z',
#  'state': 'SUCCEEDED',
#  'trainingOutput': {'completedTrialCount': '50',
#   'trials': [{'trialId': '8',
#     'hyperparameters': {'min_child_samples': '3',
#      'max_depth': '12',
#      'num_leaves': '904',
#      'subsample': '0.53888672046507569',
#      'subsample_freq': '30',
#      'reg_alpha': '17.505540018496291',
#      'n_estimators': '128',
#      'reg_lambda': '44.621424839414395',
#      'min_child_weight': '54.744592143232175',
#      'learning_rate': '0.13547765649557106',
#      'colsample_bytree': '0.9285238010883331',
#      'min_split_gain': '0.37611217682178205'},
#     'finalMetric': {'trainingStep': '1',
#      'objectiveValue': 0.03508011721751628},
#     'startTime': '2019-10-04T18:12:26.833157261Z',
#     'endTime': '2019-10-04T18:14:01Z',
#     'state': 'SUCCEEDED'},
#    {'trialId': '3',
#     'hyperparameters': {'min_child_weight': '73.481852030569868',
#      'learning_rate': '0.018850659930705949',
#      'colsample_bytree': '0.78383399808406828',
#      'min_split_gain': '0.51444633190448474',
#      'min_child_samples': '40',
#      'max_depth': '21',
#      'num_leaves': '319',
#      'subsample': '0.7575636176332351',
#      'subsample_freq': '37',
#      'reg_alpha': '34.326578741488234',
#      'n_estimators': '277',
#      'reg_lambda': '52.198522255338474'},
#     'finalMetric': {'trainingStep': '1',
#      'objectiveValue': 0.035791363976582634},
#     'startTime': '2019-10-04T18:12:26.832215896Z',
#     'endTime': '2019-10-04T18:14:01Z',
#     'state': 'SUCCEEDED'},
#    {'trialId': '9',
#     'hyperparameters': {'min_child_samples': '40',
#      'max_depth': '12',
#      'num_leaves': '636',
#      'subsample': '0.90642651760578152',
#      'subsample_freq': '43',
#      'reg_alpha': '2.1209359169006348',
#      'n_estimators': '665',
#      'reg_lambda': '46.882200241088867',
#      'min_child_weight': '48.182063918948167',
#      'learning_rate': '0.250788277053833',
#      'colsample_bytree': '0.49349821782112124',
#      'min_split_gain': '0.55029261112213135'},
#     'finalMetric': {'trainingStep': '1',
#      'objectiveValue': 0.036003585650240956},
#     'startTime': '2019-10-04T18:12:26.833361694Z',
#     'endTime': '2019-10-04T18:13:42Z',
#     'state': 'SUCCEEDED'},
#    {'trialId': '40',
#     'hyperparameters': {'colsample_bytree': '0.94341257705693493',
#      'min_split_gain': '0.45979025307035659',
#      'min_child_samples': '51',
#      'num_leaves': '631',
#      'max_depth': '16',
#      'subsample': '0.74985648527208382',
#      'subsample_freq': '31',
#      'reg_alpha': '0.86525908779260252',
#      'n_estimators': '626',
#      'reg_lambda': '50.085364924184027',
#      'min_child_weight': '50.031936911821767',
#      'learning_rate': '0.7340761098536287'},
#     'finalMetric': {'trainingStep': '1',
#      'objectiveValue': 0.03835037606620841},
#     'startTime': '2019-10-04T18:25:48.781442861Z',
#     'endTime': '2019-10-04T18:27:12Z',
#     'state': 'SUCCEEDED'},
#    {'trialId': '19',
#     'hyperparameters': {'num_leaves': '333',
#      'max_depth': '36',
#      'subsample': '0.59523711156845094',
#      'subsample_freq': '64',
#      'reg_alpha': '80.806624889373779',
#      'n_estimators': '95',
#      'reg_lambda': '90.049159526824951',
#      'min_child_weight': '3.5668837400674818',
#      'learning_rate': '0.1355161969780922',
#      'colsample_bytree': '0.3536513320207596',
#      'min_split_gain': '0.64658606052398682',
#      'min_child_samples': '69'},
#     'finalMetric': {'trainingStep': '1',
#      'objectiveValue': 0.03940378555622953},
#     'startTime': '2019-10-04T18:16:44.288100235Z',
#     'endTime': '2019-10-04T18:18:08Z',
#     'state': 'SUCCEEDED'},
#    {'trialId': '42',
#     'hyperparameters': {'reg_lambda': '53.957126876035154',
#      'min_child_weight': '54.841792018362661',
#      'learning_rate': '0.68948852095573909',
#      'colsample_bytree': '0.456390330746628',
#      'min_split_gain': '0.37047111257684451',
#      'min_child_samples': '14',
#      'num_leaves': '906',
#      'max_depth': '22',
#      'subsample': '0.99586144912781172',
#      'subsample_freq': '34',
#      'reg_alpha': '5.1597927899672325',
#      'n_estimators': '103'},
#     'finalMetric': {'trainingStep': '1',
#      'objectiveValue': 0.03943242469138766},
#     'startTime': '2019-10-04T18:28:59.076738181Z',
#     'endTime': '2019-10-04T18:30:40Z',
#     'state': 'SUCCEEDED'},
#    {'trialId': '30',
#     'hyperparameters': {'min_split_gain': '0.50294053419758611',
#      'min_child_samples': '21',
#      'max_depth': '70',
#      'num_leaves': '200',
#      'subsample': '0.52864225043809521',
#      'subsample_freq': '64',
#      'reg_alpha': '76.513992395284731',
#      'n_estimators': '398',
#      'reg_lambda': '75.279814617060453',
#      'min_child_weight': '7.662009557837429',
#      'learning_rate': '0.1382244994517981',
#      'colsample_bytree': '0.40937307696399766'},
#     'finalMetric': {'trainingStep': '1',
#      'objectiveValue': 0.03978972166516346},
#     'startTime': '2019-10-04T18:21:01.250492217Z',
#     'endTime': '2019-10-04T18:22:37Z',
#     'state': 'SUCCEEDED'},
#    {'trialId': '11',
#     'hyperparameters': {'colsample_bytree': '0.77441433000564575',
#      'min_split_gain': '0.026181459426879883',
#      'min_child_samples': '166',
#      'num_leaves': '107',
#      'max_depth': '54',
#      'subsample': '0.77417079079151152',
#      'subsample_freq': '86',
#      'reg_alpha': '86.498260498046875',
#      'n_estimators': '268',
#      'reg_lambda': '44.767165184020996',
#      'min_child_weight': '5.3136995961666109',
#      'learning_rate': '0.31826316589117049'},
#     'finalMetric': {'trainingStep': '1',
#      'objectiveValue': 0.04008582043791496},
#     'startTime': '2019-10-04T18:16:43.217133491Z',
#     'endTime': '2019-10-04T18:18:24Z',
#     'state': 'SUCCEEDED'},
#    {'trialId': '32',
#     'hyperparameters': {'n_estimators': '228',
#      'reg_lambda': '89.7511702689194',
#      'min_child_weight': '75.766851438043844',
#      'learning_rate': '0.10906885737995499',
#      'colsample_bytree': '0.59252717804432142',
#      'min_split_gain': '0.74506102389922191',
#      'min_child_samples': '148',
#      'num_leaves': '924',
#      'max_depth': '67',
#      'subsample': '0.36927544036856219',
#      'subsample_freq': '25',
#      'reg_alpha': '74.8827363406056'},
#     'finalMetric': {'trainingStep': '1',
#      'objectiveValue': 0.040195957759142566},
#     'startTime': '2019-10-04T18:25:45.277373836Z',
#     'endTime': '2019-10-04T18:27:03Z',
#     'state': 'SUCCEEDED'},
#    {'trialId': '47',
#     'hyperparameters': {'min_child_samples': '43',
#      'max_depth': '88',
#      'num_leaves': '609',
#      'subsample': '0.69069077315956284',
#      'subsample_freq': '81',
#      'reg_alpha': '47.522666914468005',
#      'n_estimators': '522',
#      'reg_lambda': '41.331296093114304',
#      'min_child_weight': '14.477689254277474',
#      'learning_rate': '0.32266246447599334',
#      'colsample_bytree': '0.75222401170055408',
#      'min_split_gain': '0.69535887250286321'},
#     'finalMetric': {'trainingStep': '1',
#      'objectiveValue': 0.040477855251288816},
#     'startTime': '2019-10-04T18:30:06.260494950Z',
#     'endTime': '2019-10-04T18:31:48Z',
#     'state': 'SUCCEEDED'},
#    {'trialId': '33',
#     'hyperparameters': {'min_child_samples': '96',
#      'max_depth': '67',
#      'num_leaves': '406',
#      'subsample': '0.99999736926056693',
#      'subsample_freq': '75',
#      'reg_alpha': '81.269376858514235',
#      'n_estimators': '298',
#      'reg_lambda': '28.162573922744002',
#      'min_child_weight': '44.746882267215511',
#      'learning_rate': '0.35587133723708547',
#      'colsample_bytree': '0.63911773790030091',
#      'min_split_gain': '0.078883627216551525'},
#     'finalMetric': {'trainingStep': '1',
#      'objectiveValue': 0.04129179901942023},
#     'startTime': '2019-10-04T18:25:45.277676962Z',
#     'endTime': '2019-10-04T18:27:23Z',
#     'state': 'SUCCEEDED'},
#    {'trialId': '10',
#     'hyperparameters': {'min_child_samples': '182',
#      'max_depth': '69',
#      'num_leaves': '920',
#      'subsample': '0.55194264663803949',
#      'subsample_freq': '2',
#      'reg_alpha': '15.1644141777702',
#      'n_estimators': '129',
#      'reg_lambda': '53.7787519652268',
#      'min_child_weight': '75.454518464402724',
#      'learning_rate': '0.917388277053833',
#      'colsample_bytree': '0.99299821782112119',
#      'min_split_gain': '0.16567722650674677'},
#     'finalMetric': {'trainingStep': '1',
#      'objectiveValue': 0.04207202593219304},
#     'startTime': '2019-10-04T18:12:26.833542643Z',
#     'endTime': '2019-10-04T18:13:49Z',
#     'state': 'SUCCEEDED'},
#    {'trialId': '23',
#     'hyperparameters': {'min_child_weight': '18.97445628189147',
#      'learning_rate': '0.89043442852419463',
#      'colsample_bytree': '0.50428801339086493',
#      'min_split_gain': '0.39857063406631177',
#      'min_child_samples': '31',
#      'num_leaves': '631',
#      'max_depth': '12',
#      'subsample': '0.734889873749324',
#      'subsample_freq': '15',
#      'reg_alpha': '20.783040315313706',
#      'n_estimators': '662',
#      'reg_lambda': '57.163893815372631'},
#     'finalMetric': {'trainingStep': '1',
#      'objectiveValue': 0.04266956698484604},
#     'startTime': '2019-10-04T18:20:27.983179114Z',
#     'endTime': '2019-10-04T18:21:52Z',
#     'state': 'SUCCEEDED'},
#    {'trialId': '46',
#     'hyperparameters': {'colsample_bytree': '0.79298735749539861',
#      'min_split_gain': '0.29252207955968745',
#      'min_child_samples': '44',
#      'max_depth': '16',
#      'num_leaves': '320',
#      'subsample': '0.59207522715490868',
#      'subsample_freq': '27',
#      'reg_alpha': '34.985921209838587',
#      'n_estimators': '277',
#      'reg_lambda': '50.545703489130837',
#      'min_child_weight': '72.841459345139228',
#      'learning_rate': '0.52505435881726337'},
#     'finalMetric': {'trainingStep': '1',
#      'objectiveValue': 0.04302046976520207},
#     'startTime': '2019-10-04T18:30:06.259867336Z',
#     'endTime': '2019-10-04T18:31:31Z',
#     'state': 'SUCCEEDED'},
#    {'trialId': '49',
#     'hyperparameters': {'colsample_bytree': '0.62882345841608789',
#      'min_split_gain': '0.47529846855752123',
#      'min_child_samples': '51',
#      'num_leaves': '728',
#      'max_depth': '34',
#      'subsample': '0.68676045777677663',
#      'subsample_freq': '89',
#      'reg_alpha': '53.242153556324489',
#      'n_estimators': '199',
#      'reg_lambda': '59.463090947905208',
#      'min_child_weight': '40.472649569182586',
#      'learning_rate': '0.44568865526463819'},
#     'finalMetric': {'trainingStep': '1',
#      'objectiveValue': 0.043669294437610036},
#     'startTime': '2019-10-04T18:30:06.268507396Z',
#     'endTime': '2019-10-04T18:31:39Z',
#     'state': 'SUCCEEDED'},
#    {'trialId': '18',
#     'hyperparameters': {'colsample_bytree': '0.97744457697868348',
#      'min_split_gain': '0.87558356615213251',
#      'min_child_samples': '157',
#      'num_leaves': '484',
#      'max_depth': '54',
#      'subsample': '0.29325124432194605',
#      'subsample_freq': '25',
#      'reg_alpha': '81.952753792638362',
#      'n_estimators': '521',
#      'reg_lambda': '85.840829487504635',
#      'min_child_weight': '65.8025487542911',
#      'learning_rate': '0.31058391515016542'},
#     'finalMetric': {'trainingStep': '1',
#      'objectiveValue': 0.04428211006135391},
#     'startTime': '2019-10-04T18:16:44.287879038Z',
#     'endTime': '2019-10-04T18:18:23Z',
#     'state': 'SUCCEEDED'},
#    {'trialId': '26',
#     'hyperparameters': {'max_depth': '71',
#      'num_leaves': '569',
#      'subsample': '0.43942236243435739',
#      'subsample_freq': '75',
#      'reg_alpha': '50.474421317671791',
#      'n_estimators': '540',
#      'reg_lambda': '16.141344749082375',
#      'min_child_weight': '1.4855292099009987',
#      'learning_rate': '0.516764798738584',
#      'colsample_bytree': '0.767289648888121',
#      'min_split_gain': '0.58942730080425787',
#      'min_child_samples': '88'},
#     'finalMetric': {'trainingStep': '1',
#      'objectiveValue': 0.04496823077222691},
#     'startTime': '2019-10-04T18:20:28.048903639Z',
#     'endTime': '2019-10-04T18:22:03Z',
#     'state': 'SUCCEEDED'},
#    {'trialId': '36',
#     'hyperparameters': {'min_child_weight': '42.769926906925392',
#      'learning_rate': '0.23185645977875805',
#      'colsample_bytree': '0.25189843573516213',
#      'min_split_gain': '0.22584824610363974',
#      'min_child_samples': '53',
#      'max_depth': '90',
#      'num_leaves': '597',
#      'subsample': '0.35033768599207565',
#      'subsample_freq': '67',
#      'reg_alpha': '62.467364325651232',
#      'n_estimators': '524',
#      'reg_lambda': '57.117635564375256'},
#     'finalMetric': {'trainingStep': '1',
#      'objectiveValue': 0.04546495672682747},
#     'startTime': '2019-10-04T18:25:45.278601795Z',
#     'endTime': '2019-10-04T18:27:09Z',
#     'state': 'SUCCEEDED'},
#    {'trialId': '24',
#     'hyperparameters': {'colsample_bytree': '0.34678846529052065',
#      'min_split_gain': '0.55745731804294962',
#      'min_child_samples': '65',
#      'num_leaves': '586',
#      'max_depth': '60',
#      'subsample': '0.12992759848274257',
#      'subsample_freq': '79',
#      'reg_alpha': '63.54183036216876',
#      'n_estimators': '522',
#      'reg_lambda': '65.285191508391918',
#      'min_child_weight': '28.147721356402613',
#      'learning_rate': '0.079570173023056315'},
#     'finalMetric': {'trainingStep': '1',
#      'objectiveValue': 0.046090649604303716},
#     'startTime': '2019-10-04T18:20:28.017292282Z',
#     'endTime': '2019-10-04T18:21:53Z',
#     'state': 'SUCCEEDED'},
#    {'trialId': '41',
#     'hyperparameters': {'n_estimators': '508',
#      'reg_lambda': '37.753549940764316',
#      'min_child_weight': '36.445438328168692',
#      'learning_rate': '0.80088454410470256',
#      'colsample_bytree': '0.35894895929663911',
#      'min_split_gain': '0.027084485309815109',
#      'min_child_samples': '50',
#      'max_depth': '67',
#      'num_leaves': '631',
#      'subsample': '0.85466306329172692',
#      'subsample_freq': '50',
#      'reg_alpha': '61.48836156248472'},
#     'finalMetric': {'trainingStep': '1',
#      'objectiveValue': 0.048391906344447545},
#     'startTime': '2019-10-04T18:28:59.146350599Z',
#     'endTime': '2019-10-04T18:30:32Z',
#     'state': 'SUCCEEDED'},
#    {'trialId': '16',
#     'hyperparameters': {'n_estimators': '327',
#      'reg_lambda': '11.674153393712539',
#      'min_child_weight': '26.671721329656517',
#      'learning_rate': '0.2158640572786332',
#      'colsample_bytree': '0.21128414285182953',
#      'min_split_gain': '0.59386554131141078',
#      'min_child_samples': '58',
#      'num_leaves': '584',
#      'max_depth': '86',
#      'subsample': '0.75543130206292675',
#      'subsample_freq': '24',
#      'reg_alpha': '67.9960390795832'},
#     'finalMetric': {'trainingStep': '1',
#      'objectiveValue': 0.04863252266138956},
#     'startTime': '2019-10-04T18:16:44.287431885Z',
#     'endTime': '2019-10-04T18:18:06Z',
#     'state': 'SUCCEEDED'},
#    {'trialId': '22',
#     'hyperparameters': {'colsample_bytree': '0.45761139969429948',
#      'min_split_gain': '0.0995001606633017',
#      'min_child_samples': '56',
#      'max_depth': '38',
#      'num_leaves': '624',
#      'subsample': '0.7189764734120786',
#      'subsample_freq': '79',
#      'reg_alpha': '63.847720262562071',
#      'n_estimators': '546',
#      'reg_lambda': '24.8751351604652',
#      'min_child_weight': '14.664736066724089',
#      'learning_rate': '0.62879121553272233'},
#     'finalMetric': {'trainingStep': '1',
#      'objectiveValue': 0.048671501569859735},
#     'startTime': '2019-10-04T18:20:27.982556399Z',
#     'endTime': '2019-10-04T18:21:50Z',
#     'state': 'SUCCEEDED'},
#    {'trialId': '21',
#     'hyperparameters': {'learning_rate': '0.53076019986964651',
#      'colsample_bytree': '0.5003483067248915',
#      'min_split_gain': '0.1062727278723874',
#      'min_child_samples': '93',
#      'num_leaves': '398',
#      'max_depth': '68',
#      'subsample': '0.97493694158345012',
#      'subsample_freq': '62',
#      'reg_alpha': '73.10865176273056',
#      'n_estimators': '306',
#      'reg_lambda': '25.193534669612806',
#      'min_child_weight': '52.12117067684656'},
#     'finalMetric': {'trainingStep': '1',
#      'objectiveValue': 0.04891232727633318},
#     'startTime': '2019-10-04T18:20:27.982914532Z',
#     'endTime': '2019-10-04T18:21:59Z',
#     'state': 'SUCCEEDED'},
#    {'trialId': '17',
#     'hyperparameters': {'n_estimators': '407',
#      'reg_lambda': '78.9442777633667',
#      'min_child_weight': '38.530094208836552',
#      'learning_rate': '0.64388391515016552',
#      'colsample_bytree': '0.47794457697868348',
#      'min_split_gain': '0.26019895076751709',
#      'min_child_samples': '14',
#      'num_leaves': '200',
#      'max_depth': '92',
#      'subsample': '0.64773511528968808',
#      'subsample_freq': '66',
#      'reg_alpha': '68.9092755317688'},
#     'finalMetric': {'trainingStep': '1',
#      'objectiveValue': 0.04915979174111404},
#     'startTime': '2019-10-04T18:16:44.287668307Z',
#     'endTime': '2019-10-04T18:18:16Z',
#     'state': 'SUCCEEDED'},
#    {'trialId': '43',
#     'hyperparameters': {'reg_alpha': '76.192877364094173',
#      'n_estimators': '527',
#      'reg_lambda': '26.666713209067794',
#      'min_child_weight': '14.440379138110432',
#      'learning_rate': '0.38734352249997656',
#      'colsample_bytree': '0.519568175407777',
#      'min_split_gain': '0.51216962640559216',
#      'min_child_samples': '61',
#      'num_leaves': '633',
#      'max_depth': '54',
#      'subsample': '0.18570290361778743',
#      'subsample_freq': '98'},
#     'finalMetric': {'trainingStep': '1',
#      'objectiveValue': 0.04944071007847007},
#     'startTime': '2019-10-04T18:28:59.145765219Z',
#     'endTime': '2019-10-04T18:30:17Z',
#     'state': 'SUCCEEDED'},
#    {'trialId': '48',
#     'hyperparameters': {'subsample': '0.77462924643473929',
#      'subsample_freq': '61',
#      'reg_alpha': '48.225965621529014',
#      'n_estimators': '548',
#      'reg_lambda': '16.925237995014797',
#      'min_child_weight': '10.937262602472464',
#      'learning_rate': '0.62179906518068029',
#      'colsample_bytree': '0.48497775993919057',
#      'min_split_gain': '0.6620403460309725',
#      'min_child_samples': '48',
#      'max_depth': '49',
#      'num_leaves': '647'},
#     'finalMetric': {'trainingStep': '1',
#      'objectiveValue': 0.05033266258451231},
#     'startTime': '2019-10-04T18:30:06.264456612Z',
#     'endTime': '2019-10-04T18:31:22Z',
#     'state': 'SUCCEEDED'},
#    {'trialId': '6',
#     'hyperparameters': {'colsample_bytree': '0.67877380108833318',
#      'min_split_gain': '0.14534294605255127',
#      'min_child_samples': '88',
#      'max_depth': '69',
#      'num_leaves': '383',
#      'subsample': '0.60333833336830134',
#      'subsample_freq': '39',
#      'reg_alpha': '60.983800888061523',
#      'n_estimators': '319',
#      'reg_lambda': '20.483493804931641',
#      'min_child_weight': '63.835410325050347',
#      'learning_rate': '0.80207765649557117'},
#     'finalMetric': {'trainingStep': '1',
#      'objectiveValue': 0.051605220536482914},
#     'startTime': '2019-10-04T18:12:26.832790655Z',
#     'endTime': '2019-10-04T18:13:49Z',
#     'state': 'SUCCEEDED'},
#    {'trialId': '14',
#     'hyperparameters': {'colsample_bytree': '0.96053414285182948',
#      'min_split_gain': '0.74771169515756464',
#      'min_child_samples': '171',
#      'max_depth': '29',
#      'num_leaves': '537',
#      'subsample': '0.72320549561131386',
#      'subsample_freq': '11',
#      'reg_alpha': '72.343865166539729',
#      'n_estimators': '59',
#      'reg_lambda': '28.915532704057366',
#      'min_child_weight': '8.490084966020147',
#      'learning_rate': '0.660264057278633'},
#     'finalMetric': {'trainingStep': '1',
#      'objectiveValue': 0.05205663846375297},
#     'startTime': '2019-10-04T18:16:44.286961444Z',
#     'endTime': '2019-10-04T18:17:58Z',
#     'state': 'SUCCEEDED'},
#    {'trialId': '38',
#     'hyperparameters': {'min_split_gain': '0.22097202078813671',
#      'min_child_samples': '53',
#      'max_depth': '71',
#      'num_leaves': '577',
#      'subsample': '0.3943039707253162',
#      'subsample_freq': '76',
#      'reg_alpha': '20.059999756142744',
#      'n_estimators': '505',
#      'reg_lambda': '2.0811745665932468',
#      'min_child_weight': '35.592456045257933',
#      'learning_rate': '0.90413883362458536',
#      'colsample_bytree': '0.705299836725742'},
#     'finalMetric': {'trainingStep': '1',
#      'objectiveValue': 0.05337455765680721},
#     'startTime': '2019-10-04T18:25:45.290091891Z',
#     'endTime': '2019-10-04T18:26:32Z',
#     'state': 'SUCCEEDED'},
#    {'trialId': '1',
#     'hyperparameters': {'subsample': '0.82201523053646086',
#      'subsample_freq': '46',
#      'reg_alpha': '77.804839611053467',
#      'n_estimators': '468',
#      'reg_lambda': '28.060591220855713',
#      'min_child_weight': '82.572670212388033',
#      'learning_rate': '0.685450659930706',
#      'colsample_bytree': '0.53408399808406826',
#      'min_split_gain': '0.28367710113525391',
#      'min_child_samples': '126',
#      'max_depth': '78',
#      'num_leaves': '698'},
#     'finalMetric': {'trainingStep': '1',
#      'objectiveValue': 0.05351704372676053},
#     'startTime': '2019-10-04T18:12:26.831654016Z',
#     'endTime': '2019-10-04T18:13:51Z',
#     'state': 'SUCCEEDED'},
#    {'trialId': '28',
#     'hyperparameters': {'colsample_bytree': '0.81318191353487079',
#      'min_split_gain': '0.055770263287955091',
#      'min_child_samples': '168',
#      'max_depth': '62',
#      'num_leaves': '212',
#      'subsample': '0.95439750072712037',
#      'subsample_freq': '37',
#      'reg_alpha': '99.105495921783728',
#      'n_estimators': '419',
#      'reg_lambda': '59.87090771048873',
#      'min_child_weight': '60.132045985292969',
#      'learning_rate': '0.73506156883256313'},
#     'finalMetric': {'trainingStep': '1',
#      'objectiveValue': 0.05616804016035348},
#     'startTime': '2019-10-04T18:21:01.245258108Z',
#     'endTime': '2019-10-04T18:22:15Z',
#     'state': 'SUCCEEDED'},
#    {'trialId': '45',
#     'hyperparameters': {'min_child_weight': '23.714574153242566',
#      'learning_rate': '0.85381503164114458',
#      'colsample_bytree': '0.719955235788372',
#      'min_split_gain': '0.7735948517611797',
#      'min_child_samples': '61',
#      'max_depth': '9',
#      'num_leaves': '642',
#      'subsample': '0.047877754985477659',
#      'subsample_freq': '42',
#      'reg_alpha': '1.6934934844095695',
#      'n_estimators': '638',
#      'reg_lambda': '57.698810421231173'},
#     'finalMetric': {'trainingStep': '1',
#      'objectiveValue': 0.059150287814622934},
#     'startTime': '2019-10-04T18:29:32.982332340Z',
#     'endTime': '2019-10-04T18:31:03Z',
#     'state': 'SUCCEEDED'},
#    {'trialId': '27',
#     'hyperparameters': {'n_estimators': '526',
#      'reg_lambda': '17.995584984579537',
#      'min_child_weight': '22.281119056009228',
#      'learning_rate': '0.98463262227324133',
#      'colsample_bytree': '0.32360389107060161',
#      'min_split_gain': '0.37761675392658667',
#      'min_child_samples': '17',
#      'num_leaves': '597',
#      'max_depth': '63',
#      'subsample': '0.72512978271175876',
#      'subsample_freq': '79',
#      'reg_alpha': '71.093294118218651'},
#     'finalMetric': {'trainingStep': '1',
#      'objectiveValue': 0.061238033962692895},
#     'startTime': '2019-10-04T18:21:01.243184178Z',
#     'endTime': '2019-10-04T18:22:24Z',
#     'state': 'SUCCEEDED'},
#    {'trialId': '29',
#     'hyperparameters': {'colsample_bytree': '0.61714361424116193',
#      'min_split_gain': '0.42098371323498762',
#      'min_child_samples': '31',
#      'num_leaves': '395',
#      'max_depth': '30',
#      'subsample': '0.093753456549077588',
#      'subsample_freq': '21',
#      'reg_alpha': '22.173701092239817',
#      'n_estimators': '477',
#      'reg_lambda': '84.790947259147217',
#      'min_child_weight': '74.727618211699408',
#      'learning_rate': '0.805284088864474'},
#     'finalMetric': {'trainingStep': '1',
#      'objectiveValue': 0.06346842161661592},
#     'startTime': '2019-10-04T18:21:01.250158754Z',
#     'endTime': '2019-10-04T18:22:21Z',
#     'state': 'SUCCEEDED'},
#    {'trialId': '4',
#     'hyperparameters': {'colsample_bytree': '0.28433399808406828',
#      'min_split_gain': '0.74521556267371547',
#      'min_child_samples': '154',
#      'num_leaves': '129',
#      'max_depth': '97',
#      'subsample': '0.49975716602033171',
#      'subsample_freq': '18',
#      'reg_alpha': '86.5004917849665',
#      'n_estimators': '200',
#      'reg_lambda': '17.715763634648816',
#      'min_child_weight': '28.027761121478953',
#      'learning_rate': '0.907650659930706'},
#     'finalMetric': {'trainingStep': '1',
#      'objectiveValue': 0.06388001401223498},
#     'startTime': '2019-10-04T18:12:26.832414628Z',
#     'endTime': '2019-10-04T18:14:06Z',
#     'state': 'SUCCEEDED'},
#    {'trialId': '34',
#     'hyperparameters': {'colsample_bytree': '0.87952294744627335',
#      'min_split_gain': '0.052984907213281307',
#      'min_child_samples': '36',
#      'max_depth': '34',
#      'num_leaves': '413',
#      'subsample': '0.18141052195845855',
#      'subsample_freq': '27',
#      'reg_alpha': '32.190889545412936',
#      'n_estimators': '432',
#      'reg_lambda': '90.480420584543907',
#      'min_child_weight': '54.596198419321361',
#      'learning_rate': '0.85365472779764584'},
#     'finalMetric': {'trainingStep': '1',
#      'objectiveValue': 0.06829434459799917},
#     'startTime': '2019-10-04T18:25:45.277996269Z',
#     'endTime': '2019-10-04T18:27:24Z',
#     'state': 'SUCCEEDED'},
#    {'trialId': '44',
#     'hyperparameters': {'min_child_weight': '36.824466173397056',
#      'learning_rate': '0.57812068290669361',
#      'colsample_bytree': '0.13069928563031502',
#      'min_split_gain': '0.57826955030539562',
#      'min_child_samples': '85',
#      'max_depth': '13',
#      'num_leaves': '611',
#      'subsample': '0.29110502846133568',
#      'subsample_freq': '17',
#      'reg_alpha': '9.92293225206058',
#      'n_estimators': '640',
#      'reg_lambda': '46.292331339389506'},
#     'finalMetric': {'trainingStep': '1',
#      'objectiveValue': 0.06897024966594544},
#     'startTime': '2019-10-04T18:29:32.956423247Z',
#     'endTime': '2019-10-04T18:31:09Z',
#     'state': 'SUCCEEDED'},
#    {'trialId': '25',
#     'hyperparameters': {'colsample_bytree': '0.47755914142991429',
#      'min_split_gain': '0.3592210460952463',
#      'min_child_samples': '45',
#      'max_depth': '45',
#      'num_leaves': '597',
#      'subsample': '0.35396550502326546',
#      'subsample_freq': '74',
#      'reg_alpha': '82.1434099550419',
#      'n_estimators': '535',
#      'reg_lambda': '46.54242931099661',
#      'min_child_weight': '42.308046653187532',
#      'learning_rate': '0.785939883370168'},
#     'finalMetric': {'trainingStep': '1',
#      'objectiveValue': 0.07123998722139703},
#     'startTime': '2019-10-04T18:20:28.048496736Z',
#     'endTime': '2019-10-04T18:21:59Z',
#     'state': 'SUCCEEDED'},
#    {'trialId': '31',
#     'hyperparameters': {'min_child_samples': '58',
#      'max_depth': '38',
#      'num_leaves': '740',
#      'subsample': '0.18896103463290259',
#      'subsample_freq': '77',
#      'reg_alpha': '53.371163402265331',
#      'n_estimators': '212',
#      'reg_lambda': '69.0957400875124',
#      'min_child_weight': '51.339580849539878',
#      'learning_rate': '0.90323333245370219',
#      'colsample_bytree': '0.24783357083730742',
#      'min_split_gain': '0.76058847775343486'},
#     'finalMetric': {'trainingStep': '1',
#      'objectiveValue': 0.07176149217534204},
#     'startTime': '2019-10-04T18:25:45.276949960Z',
#     'endTime': '2019-10-04T18:27:16Z',
#     'state': 'SUCCEEDED'},
#    {'trialId': '7',
#     'hyperparameters': {'min_child_samples': '31',
#      'max_depth': '31',
#      'num_leaves': '667',
#      'subsample': '0.24885446240055933',
#      'subsample_freq': '98',
#      'reg_alpha': '74.027279148931086',
#      'n_estimators': '434',
#      'reg_lambda': '27.380045529069573',
#      'min_child_weight': '91.1078648705049',
#      'learning_rate': '0.46877765649557096',
#      'colsample_bytree': '0.17927380108833313',
#      'min_split_gain': '0.76072756143716669'},
#     'finalMetric': {'trainingStep': '1',
#      'objectiveValue': 0.07435094130277017},
#     'startTime': '2019-10-04T18:12:26.832979923Z',
#     'endTime': '2019-10-04T18:14:06Z',
#     'state': 'SUCCEEDED'},
#    {'trialId': '35',
#     'hyperparameters': {'colsample_bytree': '0.461813629629071',
#      'min_split_gain': '0.35747242082739228',
#      'min_child_samples': '44',
#      'max_depth': '44',
#      'num_leaves': '767',
#      'subsample': '0.32834009686385618',
#      'subsample_freq': '77',
#      'reg_alpha': '50.78756882938422',
#      'n_estimators': '196',
#      'reg_lambda': '43.198528707884719',
#      'min_child_weight': '53.992075210640245',
#      'learning_rate': '0.97849283605377235'},
#     'finalMetric': {'trainingStep': '1',
#      'objectiveValue': 0.07608900737965575},
#     'startTime': '2019-10-04T18:25:45.278316620Z',
#     'endTime': '2019-10-04T18:27:13Z',
#     'state': 'SUCCEEDED'},
#    {'trialId': '20',
#     'hyperparameters': {'colsample_bytree': '0.85315133202075955',
#      'min_split_gain': '0.26197067590860224',
#      'min_child_samples': '12',
#      'num_leaves': '617',
#      'max_depth': '93',
#      'subsample': '0.24075324060070885',
#      'subsample_freq': '24',
#      'reg_alpha': '93.850103150243342',
#      'n_estimators': '210',
#      'reg_lambda': '96.945711250962887',
#      'min_child_weight': '30.839338285522025',
#      'learning_rate': '0.80211619697809211'},
#     'finalMetric': {'trainingStep': '1',
#      'objectiveValue': 0.07783281438272889},
#     'startTime': '2019-10-04T18:16:44.288308249Z',
#     'endTime': '2019-10-04T18:18:01Z',
#     'state': 'SUCCEEDED'},
#    {'trialId': '12',
#     'hyperparameters': {'min_split_gain': '0.6415660748114953',
#      'min_child_samples': '109',
#      'max_depth': '16',
#      'num_leaves': '391',
#      'subsample': '0.41968691982376949',
#      'subsample_freq': '45',
#      'reg_alpha': '99.541738758916438',
#      'n_estimators': '382',
#      'reg_lambda': '51.663716908158932',
#      'min_child_weight': '32.586154141621151',
#      'learning_rate': '0.98486316589117051',
#      'colsample_bytree': '0.27491433000564575'},
#     'finalMetric': {'trainingStep': '1',
#      'objectiveValue': 0.08402023489386447},
#     'startTime': '2019-10-04T18:16:43.217436873Z',
#     'endTime': '2019-10-04T18:18:11Z',
#     'state': 'SUCCEEDED'},
#    {'trialId': '13',
#     'hyperparameters': {'n_estimators': '595',
#      'reg_lambda': '22.018980979919434',
#      'min_child_weight': '81.216630420565608',
#      'learning_rate': '0.99356405727863317',
#      'colsample_bytree': '0.46103414285182953',
#      'min_split_gain': '0.13232707977294922',
#      'min_child_samples': '29',
#      'num_leaves': '253',
#      'max_depth': '67',
#      'subsample': '0.078689366579055786',
#      'subsample_freq': '51',
#      'reg_alpha': '59.300386905670166'},
#     'finalMetric': {'trainingStep': '1',
#      'objectiveValue': 0.08647694530349238},
#     'startTime': '2019-10-04T18:16:44.286588475Z',
#     'endTime': '2019-10-04T18:18:19Z',
#     'state': 'SUCCEEDED'},
#    {'trialId': '39',
#     'hyperparameters': {'min_child_samples': '36',
#      'max_depth': '25',
#      'num_leaves': '421',
#      'subsample': '0.39206913277821492',
#      'subsample_freq': '19',
#      'reg_alpha': '43.391858993671285',
#      'n_estimators': '451',
#      'reg_lambda': '74.466201092086635',
#      'min_child_weight': '85.673705970205162',
#      'learning_rate': '0.47995709002562681',
#      'colsample_bytree': '0.10505937781240619',
#      'min_split_gain': '0.71445295431475719'},
#     'finalMetric': {'trainingStep': '1', 'objectiveValue': 0.0884371637336229},
#     'startTime': '2019-10-04T18:25:46.762741932Z',
#     'endTime': '2019-10-04T18:27:16Z',
#     'state': 'SUCCEEDED'},
#    {'trialId': '37',
#     'hyperparameters': {'colsample_bytree': '0.0967371127326153',
#      'min_split_gain': '0.84776999753673343',
#      'min_child_samples': '50',
#      'max_depth': '73',
#      'num_leaves': '609',
#      'subsample': '0.40809785137959192',
#      'subsample_freq': '99',
#      'reg_alpha': '55.646070124771832',
#      'n_estimators': '478',
#      'reg_lambda': '17.749108458951589',
#      'min_child_weight': '53.23679767232624',
#      'learning_rate': '0.6389987286631047'},
#     'finalMetric': {'trainingStep': '1',
#      'objectiveValue': 0.10042635009285178},
#     'startTime': '2019-10-04T18:25:45.278902945Z',
#     'endTime': '2019-10-04T18:27:08Z',
#     'state': 'SUCCEEDED'},
#    {'trialId': '15',
#     'hyperparameters': {'max_depth': '10',
#      'num_leaves': '774',
#      'subsample': '0.014237753675830037',
#      'subsample_freq': '43',
#      'reg_alpha': '15.822126036104933',
#      'n_estimators': '403',
#      'reg_lambda': '46.156912014402188',
#      'min_child_weight': '72.125812238747429',
#      'learning_rate': '0.32696405727863304',
#      'colsample_bytree': '0.71078414285182956',
#      'min_split_gain': '0.36309631054218',
#      'min_child_samples': '143'},
#     'finalMetric': {'trainingStep': '1',
#      'objectiveValue': 0.10566740204960519},
#     'startTime': '2019-10-04T18:16:44.287205599Z',
#     'endTime': '2019-10-04T18:18:12Z',
#     'state': 'SUCCEEDED'},
#    {'trialId': '50',
#     'hyperparameters': {'min_split_gain': '0.960452854734527',
#      'min_child_samples': '73',
#      'max_depth': '69',
#      'num_leaves': '416',
#      'subsample': '0.27773101730720989',
#      'subsample_freq': '46',
#      'reg_alpha': '66.514755934742524',
#      'n_estimators': '303',
#      'reg_lambda': '29.067636415805829',
#      'min_child_weight': '84.734527071271174',
#      'learning_rate': '0.56004201464757775',
#      'colsample_bytree': '0.02981550450438759'},
#     'finalMetric': {'trainingStep': '1', 'objectiveValue': 0.1344971247728985},
#     'startTime': '2019-10-04T18:30:06.272766160Z',
#     'endTime': '2019-10-04T18:31:49Z',
#     'state': 'SUCCEEDED'},
#    {'trialId': '2',
#     'hyperparameters': {'num_leaves': '982',
#      'max_depth': '40',
#      'subsample': '0.46753135956871883',
#      'subsample_freq': '5',
#      'reg_alpha': '90.84831787192303',
#      'n_estimators': '583',
#      'reg_lambda': '34.957142944993649',
#      'min_child_weight': '9.8461247578425812',
#      'learning_rate': '0.35215065993070588',
#      'colsample_bytree': '0.0345839980840683',
#      'min_split_gain': '0.89906171651986933',
#      'min_child_samples': '69'},
#     'finalMetric': {'trainingStep': '1', 'objectiveValue': 0.1447364751033375},
#     'startTime': '2019-10-04T18:12:26.832014084Z',
#     'endTime': '2019-10-04T18:13:44Z',
#     'state': 'SUCCEEDED'},
#    {'trialId': '5',
#     'hyperparameters': {'colsample_bytree': '0.65895899808406833',
#      'min_split_gain': '0.052907870366023069',
#      'min_child_samples': '97',
#      'max_depth': '59',
#      'num_leaves': '840',
#      'subsample': '0.016370069246138347',
#      'subsample_freq': '32',
#      'reg_alpha': '64.76136135018389',
#      'n_estimators': '353',
#      'reg_lambda': '86.681280876028126',
#      'min_child_weight': '0.75530657602440832',
#      'learning_rate': '0.574350659930706'},
#     'finalMetric': {'trainingStep': '1',
#      'objectiveValue': 0.17606470315741532},
#     'startTime': '2019-10-04T18:12:26.832609968Z',
#     'endTime': '2019-10-04T18:14:07Z',
#     'state': 'SUCCEEDED'}],
#   'consumedMLUnits': 64.43,
#   'isHyperparameterTuningJob': True,
#   'hyperparameterMetricTag': 'ai4ops_lightgbm_mae_tag'},
#  'etag': 'aEK7CHVli+4='}

# %% [markdown]
# <a id="deployment"></a>
# ## Trained Model Deployment
# See AI Platform Models https://console.cloud.google.com/mlengine/models
# <br/>[back to Table Of Contents](#tc)

# %%
SCRIPT_PATH = f"{PROJECT_PATH}/model"
train_out = get_transition('transitions/dsl_transition_tuning.json')

AI_PLATFORM_MODEL_BASE_VERSION = 'v1'

TRAIN_JOB_ID = train_out.get('TRAIN_JOB_ID', '')
TRAIN_JOB_DIR = train_out.get('TRAIN_JOB_DIR', '')
TRAINED_MODEL = train_out.get('TRAINED_MODEL', '')
IS_TUNING = train_out.get('IS_TUNING', '')

# %%
SIGNATURE_SCALER = signature_transition.get('SIGNATURE_SCALER', '')
SIGNATURE_DROP_KEYS = signature_transition.get('SIGNATURE_DROP_KEYS', '')
SIGNATURE_BUCKET = signature_transition.get('SIGNATURE_BUCKET', '')

DEPLOYMENT_PATH = 'deployment'

MODEL_NAME = AI_PALTFORM_MODEL_NAME
VERSION_NAME = AI_PLATFORM_MODEL_BASE_VERSION
OBJECTIVE_VALUE_IS_MAXIMUM_NEEDED = False

artifacts_path = f'gs://{BUCKET}/{DEPLOYMENT_PATH}/{MODEL_NAME}_{VERSION_NAME}/stage'

# %%
deploy_job_input = {
  'pythonVersion': "3.5", \
  'deploymentUri': TRAIN_JOB_DIR,\
  'autoScaling':{'minNodes':1},
  'runtimeVersion': '1.13',\
  'predictionClass': 'custom_predictor.LGBMPredictor'
}

model = ModelBuilder()\
.name(AI_PALTFORM_MODEL_NAME)\
.is_tuning(True)\
.files_root(SCRIPT_PATH)\
.custom_predictor_path("custom_predictor/custom_predictor.py")\
.artifact(Artifact(f'gs://{BUCKET}/{SIGNATURE_SCALER}', "scaler.pkl", artifacts_path))\
.artifact(Artifact(f'gs://{BUCKET}/{SIGNATURE_DROP_KEYS}', "drop_keys.txt", artifacts_path))\
.build()



deploy_job_builder = AIJobBuilder()
model.train_job_id = TRAIN_JOB_ID

deploy_job = deploy_job_builder.model(model)\
.deploy_input(deploy_job_input)\
.name(f'{TRAIN_JOB_ID}_{VERSION_NAME}')\
.job_dir(TRAIN_JOB_DIR)\
.build()

# %%
deploy_executor = AIPlatformJobExecutor(session, deploy_job, 5,5)
deploy_executor.submit_deploy_model_job(VERSION_NAME, TRAIN_JOB_ID, create_new_model=False)
# Out:
# running sdist
# running egg_info
# creating custom_predictor.egg-info
# writing custom_predictor.egg-info/PKG-INFO
# writing dependency_links to custom_predictor.egg-info/dependency_links.txt
# writing top-level names to custom_predictor.egg-info/top_level.txt
# writing manifest file 'custom_predictor.egg-info/SOURCES.txt'
# reading manifest file 'custom_predictor.egg-info/SOURCES.txt'
# writing manifest file 'custom_predictor.egg-info/SOURCES.txt'
# warning: sdist: standard file not found: should have one of README, README.rst, README.txt, README.md
# running check
# warning: check: missing required meta-data: url
#
# warning: check: missing meta-data: either (author and author_email) or (maintainer and maintainer_email) must be supplied
# creating custom_predictor-1.0
# creating custom_predictor-1.0/custom_predictor.egg-info
# copying files to custom_predictor-1.0...
# copying custom_predictor.py -> custom_predictor-1.0
# copying setup.py -> custom_predictor-1.0
# copying custom_predictor.egg-info/PKG-INFO -> custom_predictor-1.0/custom_predictor.egg-info
# copying custom_predictor.egg-info/SOURCES.txt -> custom_predictor-1.0/custom_predictor.egg-info
# copying custom_predictor.egg-info/dependency_links.txt -> custom_predictor-1.0/custom_predictor.egg-info
# copying custom_predictor.egg-info/top_level.txt -> custom_predictor-1.0/custom_predictor.egg-info
# Writing custom_predictor-1.0/setup.cfg
# creating dist
# Creating tar archive
# removing 'custom_predictor-1.0' (and everything under it)
# MAX is needed: False
# Best trial path:gs://ai4ops/demo/models/lightgbm/dsl_demo_tuning_lgbm_1570212734/model_trial_8
# gs://ai4ops/demo/models/lightgbm/dsl_demo_tuning_lgbm_1570212734/model_trial_8
# {'name': 'projects/gd-gcp-techlead-experiments/models/ai4ops_lgbm_throughput/versions/v1',
#  'deploymentUri': 'gs://ai4ops/demo/models/lightgbm/dsl_demo_tuning_lgbm_1570212734/model_trial_8',
#  'createTime': '2019-10-07T13:40:03Z',
#  'runtimeVersion': '1.13',
#  'autoScaling': {'minNodes': 1},
#  'state': 'CREATING',
#  'packageUris': ['gs://ai4ops/demo/models/lightgbm/dsl_demo_tuning_lgbm_1570212734/staging/custom_predictor-1.0.tar.gz'],
#  'etag': '6grvXV+tfro=',
#  'machineType': 'mls1-c1-m2',
#  'pythonVersion': '3.5',
#  'predictionClass': 'custom_predictor.LGBMPredictor'}

# %%
transition_deployment = {
    "MODEL_NAME": MODEL_NAME,
    "VERSION_NAME": VERSION_NAME,
    "MODEL_DIR": TRAINED_MODEL,
    "STAGING_DIR": artifacts_path,
    "DEPLOYMENT": f"{DEPLOYMENT_PATH}/{MODEL_NAME}_{VERSION_NAME}",
    "SCALER": f"{DEPLOYMENT_PATH}/{MODEL_NAME}_{VERSION_NAME}/scaler.pkl",
    "DROP_KEYS": f"{DEPLOYMENT_PATH}/{MODEL_NAME}_{VERSION_NAME}/drop_keys.txt"
}

print(transition_deployment)

with open('transitions/dsl_transition_deployment.json', 'w') as file:
     file.write(json.dumps(transition_deployment))
# Out:
# {'MODEL_NAME': 'ai4ops_lgbm_throughput', 'VERSION_NAME': 'v1', 'MODEL_DIR': 'gs://ai4ops/demo/models/lightgbm/dsl_demo_tuning_lgbm_1570212734/model', 'STAGING_DIR': 'gs://ai4ops/deployment/ai4ops_lgbm_throughput_v1/stage', 'DEPLOYMENT': 'deployment/ai4ops_lgbm_throughput_v1', 'SCALER': 'deployment/ai4ops_lgbm_throughput_v1/scaler.pkl', 'DROP_KEYS': 'deployment/ai4ops_lgbm_throughput_v1/drop_keys.txt'}
